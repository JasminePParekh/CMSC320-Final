# %%
import pandas as pd
data = pd.read_csv("IMDB-Movie-Data.csv")
data = data[pd.notnull(data['Revenue (Millions)'])].reset_index()
data.drop(columns=['index'], inplace = True)
change_types = ['Rank', 'Year', 'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)', 'Metascore']
for i in change_types:
    data[[i]] = data[[i]].apply(pd.to_numeric)
data['Genre'] = data['Genre'].apply(lambda x: x.split(','))
data['Actors'] = data['Actors'].apply(lambda x: x.split(','))
data
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       9                       The Lost City of Z
# 8      10                               Passengers
# 9      11  Fantastic Beasts and Where to Find Them
# 10     12                           Hidden Figures
# 11     13                                Rogue One
# 12     14                                    Moana
# 13     15                                 Colossal
# 14     16                  The Secret Life of Pets
# 15     17                            Hacksaw Ridge
# 16     18                             Jason Bourne
# ...
